# %%
d = {"key":"val"}

# %%
d['key']

# %%
d.key

# %%
from box import Box

# %%
d = Box({"key":"val"})

# %%
d.key

# %%
def get_product(x:int,y:int) -> int:
    return x*y

# %%
get_product(x=2,y=3)

# %%
get_product(x=2,y='3')

# %%
pip install gdown

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1nbs9zgmzrS_ipM1WI3QKHpaZbFWUrqZo/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
